# %% [markdown]
# # ✨ Introdução
# Os dados utilizados nessa análise foram retirados da [kaggle](https://www.kaggle.com/datasets/prasertk/glassdoor-best-jobs-in-usa-from-20152021).

# %% [markdown]
# # 📚 Importando as bibliotecas

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns

# %% [markdown]
# # 🔍 Exploração inicial dos dados
# É o primeiro contato com os dados, é aqui que vamos entender pontos fundamentais para começar nossa análise:
#
#
# 🔹 Quais as colunas do dataframe;
#
# 🔹   O que cada linha da tabela representa;
#
# 🔹   Como cada coluna está organizada;
#
# 🔹   Quais os tipos de dados presentes;
#
# 🔹   Os dados estão completos? Há informações faltando?

# %%
df = pd.read_csv("https://raw.githubusercontent.com/moabalv/analise-dados/main/csv/glassdoor%20best%20jobs%20in%20America%20over%20time.csv")
df.head()
df.tail()
# Out:
#      year                       job  salary  satisfaction  job_openings  rank
# 295  2021       Corporate Recruiter   70959           4.4          2390    46
# 296  2021  Customer Success Manager   66041           4.1          4046    47
# 297  2021            Civil Engineer   65612           4.0          4705    48
# 298  2021         Financial Analyst   70959           3.9          6705    49
# 299  2021       Mechanical Engineer   75785           3.9          5277    50

# %%
df.salary
# Out:
# 0      111376
# 1       98074
# 2       94907
# 3       96443
# 4      122865
#         ...
# 295     70959
# 296     66041
# 297     65612
# 298     70959
# 299     75785
# Name: salary, Length: 300, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          300 non-null    int64
#  1   job           300 non-null    object
#  2   salary        300 non-null    int64
#  3   satisfaction  300 non-null    float64
#  4   job_openings  300 non-null    int64
#  5   rank          300 non-null    int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 14.2+ KB

# %%
df.iloc[100]
# Out:
# year                      2018
# job             Data Scientist
# salary                  110000
# satisfaction               4.2
# job_openings              4524
# rank                         1
# Name: 100, dtype: object

# %%
df.shape
# Out:
# (300, 6)

# %% [markdown]
# # 🔍 Seleções condicionais
# 🔹 Toda análise começa com perguntas e há várias que podem ser respondidas utilizando seleções condicionais.
#
# 🔹 Na seleção condicional separamos os dados utilizando condições booleanas, dessa forma conseguimos pegar apenas a parte do DataFrame que é interessante para a nossa análise

# %%
df_2021 = df[df.year == 2021]
# Out:
#      year                            job  salary  satisfaction  job_openings  \
# 250  2021                 Java Developer   90830           4.2         10103
# 251  2021                 Data Scientist  113736           4.1          5971
# 252  2021                Product Manager  121107           3.9         14515
# 253  2021           Enterprise Architect  131361           4.0         10069
# 254  2021                Devops Engineer  110003           4.0          6904
# 255  2021  Information Security Engineer  110000           4.0          5621
# 256  2021   Business Development Manager   82182           4.1          8827
# 257  2021                Mobile Engineer   94301           4.1          4631
# 258  2021              Software Engineer  110245           3.8         40564
# 259  2021                        Dentist  134122           4.0          4315
# 260  2021             Front End Engineer   81360           4.0          6978
# ...

# %% [markdown]
# ### Quais os melhores empregos de 2020?

# %%
jobs_2020 = df.year == 2020
jobs_2020
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 295    False
# 296    False
# 297    False
# 298    False
# 299    False
# Name: year, Length: 300, dtype: bool

# %%
df[jobs_2020][0:10]
# Out:
#      year                           job  salary  satisfaction  job_openings  \
# 200  2020            Front End Engineer  105240           3.9         13122
# 201  2020                Java Developer   83589           3.9         16136
# 202  2020                Data Scientist  107801           4.0          6542
# 203  2020               Product Manager  117713           3.8         12173
# 204  2020               DevOps Engineer  107310           3.9          6603
# 205  2020                 Data Engineer  102472           3.9          6941
# 206  2020             Software Engineer  105563           3.6         50438
# 207  2020   Speech Language Pathologist   71867           3.8         29167
# 208  2020              Strategy Manager  133067           4.3          3515
# 209  2020  Business Development Manager   78480           4.0          6560
#
#      rank
# 200     1
# 201     2
# 202     3
# 203     4
# 204     5
# 205     6
# 206     7
# 207     8
# 208     9
# 209    10

# %% [markdown]
# Podemos observar que as 7 melhores posições são de empregos que estão relacionados a tecnologia, será que em 2017 também?

# %% [markdown]
# ### Quais os melhores empregos de 2017?

# %%
df[df.year == 2017][0:11]
# Out:
#     year                     job  salary  satisfaction  job_openings  rank
# 50  2017          Data Scientist  110000           4.4          4184     1
# 51  2017         DevOps Engineer  110000           4.2          2725     2
# 52  2017           Data Engineer  106000           4.3          2599     3
# 53  2017             Tax Manager  110000           4.0          3317     4
# 54  2017       Analytics Manager  112000           4.1          1958     5
# 55  2017              HR Manager   85000           3.8          4339     6
# 56  2017  Database Administrator   93000           3.8          2877     7
# 57  2017        Strategy Manager  130000           4.3          1184     8
# 58  2017             UX Designer   92500           4.0          1691     9
# 59  2017     Solutions Architect  125000           3.7          2232    10
# 60  2017       Marketing Manager   90000           3.7          3875    11

# %% [markdown]
# ### Quais empregos tiveram um número de novas vagas acima da média?

# %%
df.job_openings.mean()
# Out:
# 7612.903333333334

# %%
media = df.job_openings.mean()
media
# Out:
# 7612.903333333334

# %%
df[df.job_openings > media].sort_values(by = 'job_openings', ascending = False)[0:10]
# Out:
#      year                   job  salary  satisfaction  job_openings  rank
# 1    2015     Software Engineer   98074           3.3        104828     2
# 206  2020     Software Engineer  105563           3.6         50438     7
# 33   2016     Software Engineer   95000           3.3         49270     9
# 159  2019     Software Engineer  104000           3.6         49007    10
# 0    2015  Physician Assistant   111376           3.5         45484     1
# 258  2021     Software Engineer  110245           3.8         40564     9
# 220  2020       Project Manager   77396           3.6         37764    21
# 186  2019    Physical Therapist   70000           3.6         34899    37
# 281  2021       Project Manager   80562           3.8         34362    32
# 231  2020    Software Developer   80429           3.5         31909    32

# %% [markdown]
# ### E os que pagam mais em 2021?
# 🔹Selecione as linhas em que a coluna year é igual a 2021;
#
# 🔹Use o método sort_values() para ordenar o dataframe utilizando o salário como parâmetro.

# %%
jobs_2021 = df.year == 2021
media = df.salary.mean()
df[(df.salary > media) & (jobs_2021)].sort_values(by = "salary", ascending = False)[0:10]
# Out:
#      year                        job  salary  satisfaction  job_openings  rank
# 279  2021  Technical Program Manager  142379           4.0          2618    30
# 259  2021                    Dentist  134122           4.0          4315    10
# 253  2021       Enterprise Architect  131361           4.0         10069     4
# 262  2021           Strategy Manager  123207           4.2          2647    13
# 252  2021            Product Manager  121107           3.9         14515     3
# 267  2021  Product Marketing Manager  120267           4.1          2998    18
# 251  2021             Data Scientist  113736           4.1          5971     2
# 268  2021                Tax Manager  111046           4.0          4052    19
# 258  2021          Software Engineer  110245           3.8         40564     9
# 294  2021            Finance Manager  110091           3.7          6623    45

# %% [markdown]
# ### Utilizando duas condições

# %%
df[(df.year == 2021) & (df.job_openings > media)]
# Out:
# Empty DataFrame
# Columns: [year, job, salary, satisfaction, job_openings, rank]
# Index: []

# %% [markdown]
# # 🔍 Agrupando dados com groupby
# 🔹 Para responder algumas perguntas pode ser necessário mexer um pouco mais nos dados, por exemplo: calcular a média salarial para cada ano? ou a quantidade de vagas abertar por ano.
#
# 🔹 Podemos descobrir as respostas para as perguntas acima utilizando o groupby, mas antes precisamos definir duas coisas:
# > 🔹Colunas a agrupar
#
# > 🔹Qual a função de agregação

# %% [markdown]
# ##Média salarial anual

# %%
colunas_alvo = ['year', 'salary']
ano_salario = df[colunas_alvo]

# %%
ano_salario.groupby('salary').mean()
# Out:
#           year
# salary
# 42000   2019.0
# 48000   2019.0
# 49000   2019.0
# 50467   2020.0
# 52022   2021.0
# ...        ...
# 135000  2017.0
# 140000  2019.0
# 142379  2021.0
# 153000  2019.0
# 200000  2017.0
#
# [188 rows x 1 columns]

# %%
colunas_alvo = ['year', 'salary']
media_salarial_anual = df[colunas_alvo].groupby('year').mean()
media_salarial_anual
# Out:
#          salary
# year
# 2015   93490.24
# 2016  100910.72
# 2017   90810.00
# 2018   91285.60
# 2019   85438.00
# 2020   86094.98
# 2021   91928.68

# %% [markdown]
# ##Média de novas vagas anual

# %%
colunas_alvo = ['year', 'job_openings']
media_novas_vagas = df[colunas_alvo].groupby('year').mean()
media_novas_vagas
# Out:
#       job_openings
# year
# 2015      15611.96
# 2016       4049.76
# 2017       3632.38
# 2018       4554.88
# 2019       9931.48
# 2020       9861.46
# 2021       7866.36

# %% [markdown]
# # 🔍 Criando colunas

# %% [markdown]
# ## 🔹 Mais seleções condicionais
# **A partir de agora vamos expandir mais nossas análises para obtermos resultados diversos!! Então será necessário que você escolha um emprego ou uma área que você queira analisar mais profundamente**
#
# 🔹 Vamos selecionar apenas as linhas do dataframe que são do emprego/área escolhida
#
# 🔹Algumas áreas que dão certo (você pode escolher outra se quiser): **Data, Software, Engineer, Manager, Electrical Engineer.**
#
# 🔹Algumas áreas que tem poucos valores, mas também dão certo são: **DevOps, Front End, Security.**

# %%
#Escolha uma área e passe como parâmetro para o método contains
empregos_selecionados = df.job.str.contains("Security")

# %%
df[empregos_selecionados]
# Out:
#      year                            job  salary  satisfaction  job_openings  \
# 88   2017  Information Security Engineer  100000           3.7          1247
# 90   2017               Security Analyst   70000           3.7          2464
# 166  2019              Security Engineer  102000           3.8          4683
# 255  2021  Information Security Engineer  110000           4.0          5621
#
#      rank
# 88     39
# 90     41
# 166    17
# 255     6

# %%
empregos_selecionados.value_counts()
# Out:
# False    296
# True       4
# Name: job, dtype: int64

# %% [markdown]
# ## 🔹 Criando uma nova coluna
# 🔹 Vamos criar uma nova coluna que diz se um emprego é ou não é um dos selecionados anteriormente.

# %%
#Crie a nova coluna que diz se um emprego é da área escolhida ou não.
nome_da_coluna = "security_jobs"
df[nome_da_coluna] = empregos_selecionados

# %% [markdown]
# ###Veja aqui a nova coluna do dataframe!

# %%
df
# Out:
#      year                           job  salary  satisfaction  job_openings  \
# 0    2015          Physician Assistant   111376           3.5         45484
# 1    2015             Software Engineer   98074           3.3        104828
# 2    2015  Business Development Manager   94907           3.5         11616
# 3    2015       Human Resources Manager   96443           3.6          8073
# 4    2015               Finance Manager  122865           3.4          9728
# ..    ...                           ...     ...           ...           ...
# 295  2021           Corporate Recruiter   70959           4.4          2390
# 296  2021      Customer Success Manager   66041           4.1          4046
# 297  2021                Civil Engineer   65612           4.0          4705
# 298  2021             Financial Analyst   70959           3.9          6705
# 299  2021           Mechanical Engineer   75785           3.9          5277
#
#      rank  security_jobs
# 0       1          False
# ...

# %% [markdown]
# # 🔍 Encontrando nossos resultados
# 🔹 Para encontrar nosso resultado, precisamos apenas fazer um groupby, agrupando tanto por ano quanto pela nossa nova coluna!

# %%
# Definindo as colunas alvo.

colunas_alvo = ['year', 'salary', 'security_jobs']

# %%
# Criando nosso grupo.

media_salarial = df[colunas_alvo].groupby(['year', 'security_jobs']).mean()
media_salarial
# Out:
#                            salary
# year security_jobs
# 2015 False           93490.240000
# 2016 False          100910.720000
# 2017 False           91052.083333
#      True            85000.000000
# 2018 False           91285.600000
# 2019 False           85100.000000
#      True           102000.000000
# 2020 False           86094.980000
# 2021 False           91559.877551
#      True           110000.000000

# %%
media_salarial.reset_index(inplace = True)

# %%
media_salarial
# Out:
#    year  security_jobs         salary
# 0  2015          False   93490.240000
# 1  2016          False  100910.720000
# 2  2017          False   91052.083333
# 3  2017           True   85000.000000
# 4  2018          False   91285.600000
# 5  2019          False   85100.000000
# 6  2019           True  102000.000000
# 7  2020          False   86094.980000
# 8  2021          False   91559.877551
# 9  2021           True  110000.000000

# %% [markdown]
# # 🔍 Criando visualizações
# 🔹 Chegou a hora de criar nosso primeiro gráfico
#
# 🔹Para criar um bom gráfico precisamos seguir alguns passos como:
#
#
# *   Definir um tamanho para a figura
# *   Criar o gráfico.
#
# *   Arrumar os limites
# *   Nomear os eixos e o gráfico

# %%
#Esse código é para grafico linha
sns.set_style("dark")
plt.figure(figsize = (12, 6))
grafico = sns.lineplot(data = media_salarial, x = 'year', y = 'salary', hue = 'security_jobs')
grafico.set_title("Comparação de média salarial e dados", fontsize = 20)
grafico.set_xlabel("Ano", fontsize = 12)
grafico.set_ylabel("Salário", fontsize = 12)
# Out:
# Text(0, 0.5, 'Salário')

# %%
sns.set_style("dark")
plt.figure(figsize = (12, 6))
grafico = sns.barplot(data = media_salarial, x = 'year', y = 'salary', hue = 'security_jobs')
grafico.set_title("Comparação de média salarial e dados", fontsize = 20)
grafico.set_xlabel("Ano", fontsize = 12)
grafico.set_ylabel("Salário", fontsize = 12)
grafico.set_ylim(0, 150000)
# Out:
# (0.0, 150000.0)

# %% [markdown]
# # 🔍 Exemplos de gráficos vistos anteriormente.

# %%
plt.figure(figsize = (7,5))
grafico = sns.scatterplot(data = df, y = 'job_openings', x = 'salary')
grafico.set_title("")
grafico.set_ylim(0, 130000)
grafico.set_ylabel("Novas vagas", fontsize = 10)
grafico.set_xlabel("Salário", fontsize = 10)
# Out:
# Text(0.5, 0, 'Salário')

# %%
plt.figure(figsize = (7,5))
grafico = sns.histplot(df.year, bins = 13, shrink = 1)
grafico.set_ylim(0, 80)
grafico.set_xlabel("Ano")
# Out:
# Text(0.5, 0, 'Ano')
